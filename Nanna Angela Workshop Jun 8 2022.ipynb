# %%
# %ls
# Out:
# LUNAR_LANDING_GUIDANCE_EQUATIONS.agc.txt
# Untitled.ipynb

# %%
helloFile = open('LUNAR_LANDING_GUIDANCE_EQUATIONS.agc.txt')

# %%
helloFile
# Out:
# <_io.TextIOWrapper name='LUNAR_LANDING_GUIDANCE_EQUATIONS.agc.txt' mode='r' encoding='UTF-8'>

# %%
helloContent = helloFile.read()

# %%
helloContent
# Out:
# '# Copyright:\tPublic domain.\n# Filename:\tLUNAR_LANDING_GUIDANCE_EQUATIONS.agc\n# Purpose: \tPart of the source code for Luminary 1A build 099.\n#\t\tIt is part of the source code for the Lunar Module\'s (LM)\n#\t\tApollo Guidance Computer (AGC), for Apollo 11.\n# Assembler:\tyaYUL\n# Contact:\tHARTMUTH GUTSCHE <hgutsche@xplornet.com>.\n# Website:\twww.ibiblio.org/apollo.\n# Pages:\t798-828\n# Mod history:\t2009-05-23 HG\tTranscribed from page images.\n#\t\t2009-06-05 RSB\tFixed a goofy thing that was apparently\n#\t\t\t\tlegal in GAP but not in yaYUL.  Eliminated\n#\t\t\t\ta couple of lines of code that shouldn\'t\n#\t\t\t\thave survived from Luminary 131 to here.\n#\t\t2009-06-07 RSB\tFixed a typo.\n#\n# This source code has been transcribed or otherwise adapted from\n# digitized images of a hardcopy from the MIT Museum.  The digitization\n# was performed by Paul Fjeld, and arranged for by Deborah Douglas of\n# the Museum.  Many thanks to both.  The images (with suitable reductio
# ...

# %%
type(helloContent)
# Out:
# str

# %%
lines=helloContent.split('\n')

# %%
lines
# Out:
# ['# Copyright:\tPublic domain.',
#  '# Filename:\tLUNAR_LANDING_GUIDANCE_EQUATIONS.agc',
#  '# Purpose: \tPart of the source code for Luminary 1A build 099.',
#  "#\t\tIt is part of the source code for the Lunar Module's (LM)",
#  '#\t\tApollo Guidance Computer (AGC), for Apollo 11.',
#  '# Assembler:\tyaYUL',
#  '# Contact:\tHARTMUTH GUTSCHE <hgutsche@xplornet.com>.',
#  '# Website:\twww.ibiblio.org/apollo.',
#  '# Pages:\t798-828',
#  '# Mod history:\t2009-05-23 HG\tTranscribed from page images.',
#  '#\t\t2009-06-05 RSB\tFixed a goofy thing that was apparently',
#  '#\t\t\t\tlegal in GAP but not in yaYUL.  Eliminated',
#  "#\t\t\t\ta couple of lines of code that shouldn't",
#  '#\t\t\t\thave survived from Luminary 131 to here.',
#  '#\t\t2009-06-07 RSB\tFixed a typo.',
#  '#',
#  '# This source code has been transcribed or otherwise adapted from',
#  '# digitized images of a hardcopy from the MIT Museum.  The digitization',
# ...

# %%
len(lines)
# Out:
# 1475

# %%
teststring= "#Entry"
teststring.find('!')
# Out:
# -1

# %%
import re

txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)
print(x)
# Out:
# <re.Match object; span=(0, 17), match='The rain in Spain'>

# %%
comments = []
for line in lines[100:300]:
    if line.find('#')==0:
        print(line)
        comments.append(line)
    else:
        print("not found",line)
# Out:
# #************************************************************************
# # ENTRY POINTS:  ?GUIDSUB FOR THE IGNITION ALGORITHM, LUNLAND FOR SERVOUT
# #************************************************************************
# not found
# # IGNITION ALGORITHM ENTRY:  DELIVERS N PASSES OF QUADRATIC GUIDANCE
# not found
# not found ?GUIDSUB	EXIT
# not found 		CAF	TWO		# N = 3
# not found 		TS	NGUIDSUB
# not found 		TCF	GUILDRET +2
# not found
# not found GUIDSUB		TS	NGUIDSUB	# ON SUCCEEDING PASSES SKIP TTFINCR
# not found 		TCF	CALCRGVG
# not found
# # NORMAL ENTRY:  CONTROL COMES HERE FROM SERVOUT
# not found
# not found LUNLAND		TC	PHASCHNG
# not found 		OCT	00035		# GROUP 5:  RETAIN ONLY PIPA TASK
# not found 		TC	PHASCHNG
# not found 		OCT	05023		# GROUP 3:  PROTECT GUIDANCE WITH PRIO 21
# not found 		OCT	21000		#	JUST HIGHER THAN SERVICER'S PRIORITY
# not found
# # Page 800
# #*******************************************************************
# ...

# %%
comments = []
for line in lines[100:300]:
    x = re.search("#", line)
    if x:
        comments.append(line)
        print("YES!",line)
    else:
        print("ignore",line)
# Out:
# YES! #************************************************************************
# YES! # ENTRY POINTS:  ?GUIDSUB FOR THE IGNITION ALGORITHM, LUNLAND FOR SERVOUT
# YES! #************************************************************************
# ignore
# YES! # IGNITION ALGORITHM ENTRY:  DELIVERS N PASSES OF QUADRATIC GUIDANCE
# ignore
# ignore ?GUIDSUB	EXIT
# YES! 		CAF	TWO		# N = 3
# ignore 		TS	NGUIDSUB
# ignore 		TCF	GUILDRET +2
# ignore
# YES! GUIDSUB		TS	NGUIDSUB	# ON SUCCEEDING PASSES SKIP TTFINCR
# ignore 		TCF	CALCRGVG
# ignore
# YES! # NORMAL ENTRY:  CONTROL COMES HERE FROM SERVOUT
# ignore
# ignore LUNLAND		TC	PHASCHNG
# YES! 		OCT	00035		# GROUP 5:  RETAIN ONLY PIPA TASK
# ignore 		TC	PHASCHNG
# YES! 		OCT	05023		# GROUP 3:  PROTECT GUIDANCE WITH PRIO 21
# YES! 		OCT	21000		#	JUST HIGHER THAN SERVICER'S PRIORITY
# ignore
# YES! # Page 800
# YES! #*******************************************************************
# YES! # GUILDENSTERN:  AUTO-MODES MONITOR (R13)
# ...

# %%
comments
# Out:
# ['#************************************************************************',
#  '# ENTRY POINTS:  ?GUIDSUB FOR THE IGNITION ALGORITHM, LUNLAND FOR SERVOUT',
#  '#************************************************************************',
#  '# IGNITION ALGORITHM ENTRY:  DELIVERS N PASSES OF QUADRATIC GUIDANCE',
#  '\t\tCAF\tTWO\t\t# N = 3',
#  'GUIDSUB\t\tTS\tNGUIDSUB\t# ON SUCCEEDING PASSES SKIP TTFINCR',
#  '# NORMAL ENTRY:  CONTROL COMES HERE FROM SERVOUT',
#  '\t\tOCT\t00035\t\t# GROUP 5:  RETAIN ONLY PIPA TASK',
#  '\t\tOCT\t05023\t\t# GROUP 3:  PROTECT GUIDANCE WITH PRIO 21',
#  "\t\tOCT\t21000\t\t#\tJUST HIGHER THAN SERVICER'S PRIORITY",
#  '# Page 800',
#  '#*******************************************************************',
#  '# GUILDENSTERN:  AUTO-MODES MONITOR (R13)',
#  '#*******************************************************************',
#  '# HERE IS THE PHILOSOPHY OF GUILDENSTERN:\tON EVERY APPEARANCE OR DISAPPEARANCE OF THE MANUAL THROTTLE',
# ...

# %%
comments = []
for line in lines:
    x = re.search("#", line)
    if x:
        comments.append(line)
        print("YES!",line)
    else:
        print("ignore",line)
# Out:
# YES! # Copyright:	Public domain.
# YES! # Filename:	LUNAR_LANDING_GUIDANCE_EQUATIONS.agc
# YES! # Purpose: 	Part of the source code for Luminary 1A build 099.
# YES! #		It is part of the source code for the Lunar Module's (LM)
# YES! #		Apollo Guidance Computer (AGC), for Apollo 11.
# YES! # Assembler:	yaYUL
# YES! # Contact:	HARTMUTH GUTSCHE <hgutsche@xplornet.com>.
# YES! # Website:	www.ibiblio.org/apollo.
# YES! # Pages:	798-828
# YES! # Mod history:	2009-05-23 HG	Transcribed from page images.
# YES! #		2009-06-05 RSB	Fixed a goofy thing that was apparently
# YES! #				legal in GAP but not in yaYUL.  Eliminated
# YES! #				a couple of lines of code that shouldn't
# YES! #				have survived from Luminary 131 to here.
# YES! #		2009-06-07 RSB	Fixed a typo.
# YES! #
# YES! # This source code has been transcribed or otherwise adapted from
# YES! # digitized images of a hardcopy from the MIT Museum.  The digitization
# ...

# %%
comments
# Out:
# ['# Copyright:\tPublic domain.',
#  '# Filename:\tLUNAR_LANDING_GUIDANCE_EQUATIONS.agc',
#  '# Purpose: \tPart of the source code for Luminary 1A build 099.',
#  "#\t\tIt is part of the source code for the Lunar Module's (LM)",
#  '#\t\tApollo Guidance Computer (AGC), for Apollo 11.',
#  '# Assembler:\tyaYUL',
#  '# Contact:\tHARTMUTH GUTSCHE <hgutsche@xplornet.com>.',
#  '# Website:\twww.ibiblio.org/apollo.',
#  '# Pages:\t798-828',
#  '# Mod history:\t2009-05-23 HG\tTranscribed from page images.',
#  '#\t\t2009-06-05 RSB\tFixed a goofy thing that was apparently',
#  '#\t\t\t\tlegal in GAP but not in yaYUL.  Eliminated',
#  "#\t\t\t\ta couple of lines of code that shouldn't",
#  '#\t\t\t\thave survived from Luminary 131 to here.',
#  '#\t\t2009-06-07 RSB\tFixed a typo.',
#  '#',
#  '# This source code has been transcribed or otherwise adapted from',
#  '# digitized images of a hardcopy from the MIT Museum.  The digitization',
# ...

# %%
len(comments)
# Out:
# 523

# %%
ignore=['\t','Page']

# %%
phrases=[]
for comment in comments:
    x = re.split("#", comment)
    for phrase in x:
        phrases.append(phrase)

# %%
phrases
# Out:
# ['\t\tDCA\tHDOTDISP\t',
#  ' SET DESIRED ALTITUDE RATE = CURRENT',
#  '\t\tDXCH\tVDGVERT\t\t',
#  ' \tALTITUDE RATE.',
#  '',
#  ' Page 801',
#  '\t\tCAF\tTWO\t\t',
#  ' WCHPHASE = 2 ---> VERTICAL: P65,P66,P67',
#  '\t\tTC\tBANKCALL\t',
#  ' TEMPORARY, I HOPE HOPE HOPE',
#  '\t\tCADR\tSTOPRATE\t',
#  ' TEMPORARY, I HOPE HOPE HOPE',
#  '\t\tTC\tDOWNFLAG\t',
#  ' PERMIT X-AXIS OVERRIDE',
#  'STARTP67\tTC\tNEWMODEX\t',
#  ' NO HARM IN "STARTING" P67 OVER AND OVER',
#  '\t\tDEC\t67\t\t',
#  ' SO NO NEED FOR A FASTCHNG AND NO NEED',
#  '\t\tCAF\tZERO\t\t',
#  ' TO SEE IF ALREADY IN P67.',
#  'STABL?\t\tCAF\tBIT13\t\t',
#  ' IS UN-ATTITUDE-HOLD DISCRETE PRESENT?',
#  '\t\tTCF\tGUILDRET\t',
#  " YES ALL'S WELL",
#  '\t\tCA\tRODCOUNT\t',
#  ' NO. HAS THE ROD SWITCH BEEN "CLICKED"?',
#  '\t\tBZF\tGUILDRET\t',
#  ' NO. CONTINUE WITH AUTOMATIC LANDING',
#  '\t\tTCF\tSTARTP66\t',
#  ' YES. SWITCH INTO THE ROD MODE.',
#  'RESTART?\tCA\tFLAGWRD1\t',
#  ' HAS THERE BEEN A RESTART?',
# ...

# %%
len(phrases)
# Out:
# 1047

# %%
phrases.sort()

# %%
phrases
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
testphrase="Test\t\tme"
print(re.sub('\t+'," ",testphrase))
# Out:
# Test me

# %%
newphrases=[]
for phrase in phrases:
    newphrase = re.sub("\t+", " ", phrase)
    newphrase = re.sub("		", "	", phrase)
    newphrases.append(newphrase.strip())

# %%
newphrases
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
desc=[]
uniqPhrases = sorted(set(phrases)) #remove duplicate words and sort
for phrase in uniqPhrases:
    print( phrases.count(phrase), phrase)
    desc.append({phrase,phrases.count(phrase)})
# Out:
# 261
# 5
# 1 					(0)
# 1 					(6)
# 1 					(8)
# 4 				(0)
# 7 				(2)
# 1 				(2), (4), OR (6)
# 4 				(4)
# 3 				(6)
# 1 				(8)
# 1 				a couple of lines of code that shouldn't
# 1 				have survived from Luminary 131 to here.
# 1 				legal in GAP but not in yaYUL.  Eliminated
# 1 			                 ____   _
# 1 			0
# 1 			ADG2TTF,1
# 1 			CG
# 1 			GAINBRAK,1
# 1 			LAND = /LAND/ UNIT(LAND - LAND(TPIP - TPIPOLD) * WM)
# 1 			MASS
# 2 			R
# 1 			RANGEDSP = ABVAL(LAND - R)
# 1 			RDG +4,1
# 1 			TTF/8 = TTF/8 + (TPIP - TPIPOLD)/8
# 1 			UNFC/2
# 1 			UNFC/2 +2
# 1 			VATT1
# 1 			VGU 	+4
# 1 			YNBPIP
# 1 			ZEROVECS
# 1 			____               ____   ____                   __
# 1 		                       2    1
# 1 		                       _   ____  ______
# 1 		                  TTF/8
# 1 		                TTF        (TTF)(TTF)
# 1 		              ___   __       ___   __
# 1 		             ___   __
# 1 		        TAUVERT
# 1 		      - (------------- + VDG + VG)
# ...

# %%
#note to remmove double tabs within columns and white space

# %%
len(uniqPhrases)
# Out:
# 675

# %%
desc
# Out:
# [{'', 261},
#  {'\t\t\t\t\t', 5},
#  {'\t\t\t\t\t(0)', 1},
#  {'\t\t\t\t\t(6)', 1},
#  {'\t\t\t\t\t(8)', 1},
#  {'\t\t\t\t(0)', 4},
#  {'\t\t\t\t(2)', 7},
#  {'\t\t\t\t(2), (4), OR (6)', 1},
#  {'\t\t\t\t(4)', 4},
#  {'\t\t\t\t(6)', 3},
#  {'\t\t\t\t(8)', 1},
#  {"\t\t\t\ta couple of lines of code that shouldn't", 1},
#  {'\t\t\t\thave survived from Luminary 131 to here.', 1},
#  {'\t\t\t\tlegal in GAP but not in yaYUL.  Eliminated', 1},
#  {'\t\t\t                 ____   _', 1},
#  {'\t\t\t0\t\t', 1},
#  {'\t\t\tADG2TTF,1\t', 1},
#  {'\t\t\tCG\t\t', 1},
#  {'\t\t\tGAINBRAK,1\t', 1},
#  {'\t\t\tLAND = /LAND/ UNIT(LAND - LAND(TPIP - TPIPOLD) * WM)', 1},
#  {'\t\t\tMASS\t\t', 1},
#  {'\t\t\tR\t\t', 2},
#  {'\t\t\tRANGEDSP = ABVAL(LAND - R)', 1},
#  {'\t\t\tRDG +4,1\t', 1},
#  {'\t\t\tTTF/8 = TTF/8 + (TPIP - TPIPOLD)/8', 1},
#  {'\t\t\tUNFC/2\t\t', 1},
#  {'\t\t\tUNFC/2 +2\t', 1},
#  {'\t\t\tVATT1\t\t', 1},
#  {'\t\t\tVGU \t+4\t', 1},
#  {'\t\t\tYNBPIP\t\t', 1},
# ...

# %%
corpus= helloContent.split()
# Out:
# ['#',
#  'Copyright:',
#  'Public',
#  'domain.',
#  '#',
#  'Filename:',
#  'LUNAR_LANDING_GUIDANCE_EQUATIONS.agc',
#  '#',
#  'Purpose:',
#  'Part',
#  'of',
#  'the',
#  'source',
#  'code',
#  'for',
#  'Luminary',
#  '1A',
#  'build',
#  '099.',
#  '#',
#  'It',
#  'is',
#  'part',
#  'of',
#  'the',
#  'source',
#  'code',
#  'for',
#  'the',
#  'Lunar',
#  "Module's",
#  '(LM)',
#  '#',
#  'Apollo',
#  'Guidance',
#  'Computer',
#  '(AGC),',
#  'for',
#  'Apollo',
#  '11.',
#  '#',
#  'Assembler:',
#  'yaYUL',
#  '#',
#  'Contact:',
#  'HARTMUTH',
#  'GUTSCHE',
#  '<hgutsche@xplornet.com>.',
#  '#',
#  'Website:',
#  'www.ibiblio.org/apollo.',
#  '#',
#  'Pages:',
#  '798-828',
#  '#',
#  'Mod',
#  'history:',
#  '2009-05-23',
#  'HG',
#  'Transcribed',
#  'from',
#  'page',
#  'images.',
#  '#',
#  '2009-06-05',
#  'RSB',
#  'Fixed',
#  'a',
#  'goofy',
#  'thing',
#  'that',
#  'was',
#  'apparently',
#  '#',
#  'legal',
#  'in',
#  'GAP',
#  'but',
#  'not',
#  'in',
# ...

# %%
for word in corpus:
    if word in sensoryarray:
        fillColor(lookup[word])
        text("word")
        positionincrement

# %%
ten most used words

# %%
phrases
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
import pandas as pd

# %%
pd.
